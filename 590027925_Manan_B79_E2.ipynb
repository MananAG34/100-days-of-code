# %% [markdown]
# <a href="https://colab.research.google.com/github/MananAG34/100-days-of-code/blob/100-days-of-code/590027925_Manan_B79_E2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# github:

# %% [markdown]
# #Experiment 02: Conditional Statements
#
# Course: Python Programming
#
# #####Name: Manan Agrawal
# #####SAPID: 590027925
# #####Batch-B79

# %% [markdown]
# 1. Divisibility by 3 and 5
#
# Check if a number is divisible by both 3 and 5 using the and operator.

# %%
num = int(input("Enter a number: "))

# A number is divisible by x if the remainder (modulus) is 0
if num % 3 == 0 and num % 5 == 0:
    print(f"{num} is divisible by both 3 and 5")
else:
    print(f"{num} is not divisible by both 3 and 5")

# %% [markdown]
# 2. Multiple of Five

# %%
num = int(input("Enter a number: "))

if num % 5 == 0:
    print(f"{num} is a multiple of 5")
else:
    print(f"{num} is not a multiple of 5")

# %% [markdown]
# 3. Greatest of Two Numbers

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

if a > b:
    print(f"{a} is greater")
elif b > a:
    print(f"{b} is greater")
else:
    print("Numbers are equal")

# %% [markdown]
# 4. Greatest of Three (Distinct)

# %%
a = int(input("Enter A: "))
b = int(input("Enter B: "))
c = int(input("Enter C: "))

if a > b and a > c:
    print(f"{a} is the greatest")
elif b > c:
    print(f"{b} is the greatest")
else:
    print(f"{c} is the greatest")

# %% [markdown]
# 5. Quadratic Equation Roots

# %%
import math

a = float(input("Enter a: "))
b = float(input("Enter b: "))
c = float(input("Enter c: "))

d = (b**2) - (4*a*c)

if d >= 0:
    root1 = (-b + math.sqrt(d)) / (2*a)
    root2 = (-b - math.sqrt(d)) / (2*a)
    print(f"Real Roots: {root1} and {root2}")
else:
    print("Roots are imaginary")

# %% [markdown]
# 6. Leap Year Check

# %%
year = int(input("Enter year: "))

# Leap year logic: divisible by 4 but not 100, unless divisible by 400
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a Leap Year")
else:
    print(f"{year} is not a Leap Year")

# %% [markdown]
# 7. Next Date Calculator

# %%
day = int(input("day="))
month = int(input("month="))
year = int(input("year="))

# Simplifying month lengths (ignoring leap year for basics, or add logic if needed)
if month in [1, 3, 5, 7, 8, 10, 12]:
    max_days = 31
elif month in [4, 6, 9, 11]:
    max_days = 30
else:
    # Basic Feb check
    max_days = 29 if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0) else 28

if day < max_days:
    day += 1
else:
    day = 1
    if month == 12:
        month = 1
        year += 1
    else:
        month += 1

print(f"Next Date: day={day} month={month} year={year}")

# %% [markdown]
# 8. Grade Sheet Generator

# %%
# Student Details
name = "Rohit Sharma"
roll = "R17234512"
sap = "50005673"

# Input Marks
pds = float(input("PDS Marks: "))
python = float(input("Python Marks: "))
chem = float(input("Chemistry Marks: "))
eng = float(input("English Marks: "))
phy = float(input("Physics Marks: "))

# Calculations
total = pds + python + chem + eng + phy
percentage = total / 5
cgpa = percentage / 10

# Grade Logic
if 9.1 <= cgpa <= 10: grade = "O"
elif 8.1 <= cgpa: grade = "A+"
elif 7.1 <= cgpa: grade = "A"
elif 6.1 <= cgpa: grade = "B+"
elif 5.1 <= cgpa: grade = "B"
elif 3.5 <= cgpa: grade = "C+"
else: grade = "F"

# Output Formatting
print("-" * 30)
print(f"Name: {name}\tRoll: {roll}")
print(f"SAPID: {sap}")
print("-" * 30)
print(f"Percentage: {percentage}%")
print(f"CGPA: {cgpa}")
print(f"Grade: {grade}")
print("-" * 30)
